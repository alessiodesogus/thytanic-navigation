# %% [markdown]
# # Basics of mobile robotics project - The Thytanic Navigation (2024)

# %% [markdown]
# ## 1. Introduction & Context
#
# | **Contributors**         | **Sciper**  | **Role**             | **Studies**                                                             |
# |---------------------------|-------------|-----------------------|---------------------------------------------------------------------------|
# | **Alessio Desogus**       | 301705      | Local Navigation      | Bachelor and Master in Mechanical Engineering.                            |
# |   **Antoine Bachmann**    |  336641     | Global navigation      | Bachelor and Master in Computer Science                                   |
# |                           |             |                       |                                                                           |
# |                           |             |                       |                                                                           |
#
# Date of deliverable: 05.12.2024
#
# Our main sources were the exercise sessions of the course and ....
#
# ### Project Description
#
#
#
#
# ### Environment

# %% [markdown]
# ## 2. Initialization

# %%
from local_navigation_and_control import ThytanicController, ThytanicState
from vision import generate_map
from global_navigation import downsamplingprep, downsampling, pathfinder
import numpy as np, matplotlib.pyplot as plt
from kalman_filtering import kalman_filter
# Out:
# label 0 is 0 pixels in size
# label 1 is 307200 pixels in size

# %%
# Initialize the ThytanicController
thytanic = ThytanicController()

# %% [markdown]
# ## 3. Vision

# %%
#turn the image into a 4-channel map

img = generate_map(background_color=np.array([119, 104, 215]),
    obstacle_color=np.array([0, 0, 0]),
    thymio_color=np.array([255, 190, 130]),
    target_color=np.array([255, 140, 100]),
    img_path="output/picture.png")
# Out:
# label 0 is 246895 pixels in size
# label 1 is 8 pixels in size
# label 2 is 3 pixels in size
# label 3 is 5 pixels in size
# label 4 is 2 pixels in size
# label 5 is 147 pixels in size
# label 6 is 40531 pixels in size
# label 7 is 2 pixels in size
# label 8 is 1 pixels in size
# label 9 is 21 pixels in size
# label 10 is 4 pixels in size
# label 11 is 6 pixels in size
# label 12 is 1 pixels in size
# label 13 is 2 pixels in size
# label 14 is 3 pixels in size
# label 15 is 2 pixels in size
# label 16 is 5 pixels in size
# label 17 is 5 pixels in size
# label 18 is 1 pixels in size
# label 19 is 84 pixels in size
# label 20 is 5 pixels in size
# label 21 is 2 pixels in size
# label 22 is 12 pixels in size
# label 23 is 14 pixels in size
# label 24 is 5 pixels in size
# label 25 is 11 pixels in size
# label 26 is 9 pixels in size
# label 27 is 2 pixels in size
# label 28 is 56 pixels in size
# label 29 is 4 pixels in size
# label 30 is 5 pixels in size
# label 31 is 20 pixels in size
# label 32 is 7 pixels in size
# label 33 is 6 pixels in size
# label 34 is 2 pixels in size
# label 35 is 3 pixels in size
# label 36 is 4 pixels in size
# label 37 is 2 pixels in size
# label 38 is 80 pixels in size
# label 39 is 12 pixels in size
# label 40 is 1 pixels in size
# label 41 is 2 pixels in size
# label 42 is 1 pixels in size
# label 43 is 4 pixels in size
# label 44 is 36 pixels in size
# label 45 is 5 pixels in size
# label 46 is 1 pixels in size
# label 47 is 2 pixels in size
# label 48 is 2 pixels in size
# label 49 is 4 pixels in size
# label 50 is 2 pixels in size
# label 51 is 3 pixels in size
# label 52 is 9 pixels in size
# label 53 is 5 pixels in size
# label 54 is 1 pixels in size
# label 55 is 6 pixels in size
# label 56 is 1 pixels in size
# label 57 is 16 pixels in size
# label 58 is 7 pixels in size
# label 59 is 13 pixels in size
# label 60 is 3 pixels in size
# label 61 is 2 pixels in size
# label 62 is 1 pixels in size
# label 63 is 2 pixels in size
# label 64 is 11 pixels in size
# label 65 is 2 pixels in size
# label 66 is 16 pixels in size
# label 67 is 1 pixels in size
# label 68 is 183 pixels in size
# label 69 is 1 pixels in size
# label 70 is 11 pixels in size
# label 71 is 13 pixels in size
# label 72 is 3 pixels in size
# label 73 is 1 pixels in size
# label 74 is 6 pixels in size
# label 75 is 1 pixels in size
# label 76 is 4 pixels in size
# label 77 is 1 pixels in size
# label 78 is 2 pixels in size
# label 79 is 2 pixels in size
# label 80 is 4 pixels in size
# label 81 is 18 pixels in size
# label 82 is 10 pixels in size
# label 83 is 2 pixels in size
# label 84 is 1 pixels in size
# label 85 is 94 pixels in size
# label 86 is 4 pixels in size
# label 87 is 5 pixels in size
# label 88 is 122 pixels in size
# label 89 is 2 pixels in size
# label 90 is 3 pixels in size
# label 91 is 78 pixels in size
# label 92 is 2 pixels in size
# label 93 is 7 pixels in size
# label 94 is 1 pixels in size
# label 95 is 103 pixels in size
# label 96 is 2 pixels in size
# label 97 is 7 pixels in size
# label 98 is 2 pixels in size
# label 99 is 4 pixels in size
# label 100 is 2 pixels in size
# label 101 is 1 pixels in size
# label 102 is 997 pixels in size
# label 103 is 6 pixels in size
# label 104 is 14 pixels in size
# label 105 is 4 pixels in size
# label 106 is 1 pixels in size
# label 107 is 1 pixels in size
# label 108 is 13 pixels in size
# label 109 is 1 pixels in size
# label 110 is 2 pixels in size
# label 111 is 1 pixels in size
# label 112 is 23 pixels in size
# label 113 is 20 pixels in size
# label 114 is 1 pixels in size
# label 115 is 2 pixels in size
# label 116 is 4 pixels in size
# label 117 is 104 pixels in size
# label 118 is 3 pixels in size
# label 119 is 14 pixels in size
# label 120 is 5 pixels in size
# label 121 is 57 pixels in size
# label 122 is 9 pixels in size
# label 123 is 3 pixels in size
# label 124 is 12 pixels in size
# label 125 is 37 pixels in size
# label 126 is 1 pixels in size
# label 127 is 1 pixels in size
# label 128 is 1 pixels in size
# label 129 is 10 pixels in size
# label 130 is 11 pixels in size
# label 131 is 4 pixels in size
# label 132 is 5 pixels in size
# label 133 is 2 pixels in size
# label 134 is 18 pixels in size
# label 135 is 32 pixels in size
# label 136 is 18 pixels in size
# label 137 is 59 pixels in size
# label 138 is 2 pixels in size
# label 139 is 1 pixels in size
# label 140 is 1 pixels in size
# label 141 is 22 pixels in size
# label 142 is 12 pixels in size
# label 143 is 7 pixels in size
# label 144 is 15 pixels in size
# label 145 is 3 pixels in size
# label 146 is 4 pixels in size
# label 147 is 1 pixels in size
# label 148 is 1 pixels in size
# label 149 is 5 pixels in size
# label 150 is 2 pixels in size
# label 151 is 3 pixels in size
# label 152 is 21 pixels in size
# label 153 is 1 pixels in size
# label 154 is 38 pixels in size
# label 155 is 3 pixels in size
# label 156 is 1 pixels in size
# label 157 is 2 pixels in size
# label 158 is 7 pixels in size
# label 159 is 2 pixels in size
# label 160 is 3 pixels in size
# label 161 is 4 pixels in size
# label 162 is 2 pixels in size
# label 163 is 1 pixels in size
# label 164 is 16 pixels in size
# label 165 is 5 pixels in size
# label 166 is 2 pixels in size
# label 167 is 11 pixels in size
# label 168 is 3 pixels in size
# label 169 is 29 pixels in size
# label 170 is 1 pixels in size
# label 171 is 11 pixels in size
# label 172 is 1 pixels in size
# label 173 is 1 pixels in size
# label 174 is 18 pixels in size
# label 175 is 2 pixels in size
# label 176 is 316 pixels in size
# label 177 is 2 pixels in size
# label 178 is 14 pixels in size
# label 179 is 3 pixels in size
# label 180 is 3 pixels in size
# label 181 is 10 pixels in size
# label 182 is 11 pixels in size
# label 183 is 3 pixels in size
# label 184 is 69 pixels in size
# label 185 is 1 pixels in size
# label 186 is 2 pixels in size
# label 187 is 3 pixels in size
# label 188 is 4 pixels in size
# label 189 is 8 pixels in size
# label 190 is 6 pixels in size
# label 191 is 1 pixels in size
# label 192 is 14 pixels in size
# label 193 is 1 pixels in size
# label 194 is 5 pixels in size
# label 195 is 17 pixels in size
# label 196 is 5 pixels in size
# label 197 is 12 pixels in size
# label 198 is 2 pixels in size
# label 199 is 5 pixels in size
# label 200 is 1 pixels in size
# label 201 is 4 pixels in size
# label 202 is 16 pixels in size
# label 203 is 2 pixels in size
# label 204 is 5 pixels in size
# label 205 is 3 pixels in size
# label 206 is 58 pixels in size
# label 207 is 4 pixels in size
# label 208 is 1 pixels in size
# label 209 is 2 pixels in size
# label 210 is 19 pixels in size
# label 211 is 2 pixels in size
# label 212 is 10464 pixels in size
# label 213 is 9 pixels in size
# label 214 is 5 pixels in size
# label 215 is 4 pixels in size
# label 216 is 2 pixels in size
# label 217 is 12 pixels in size
# label 218 is 9 pixels in size
# label 219 is 211 pixels in size
# label 220 is 1 pixels in size
# label 221 is 4 pixels in size
# label 222 is 2 pixels in size
# label 223 is 1 pixels in size
# label 224 is 21 pixels in size
# label 225 is 2 pixels in size
# label 226 is 1 pixels in size
# label 227 is 5 pixels in size
# label 228 is 26 pixels in size
# label 229 is 18 pixels in size
# label 230 is 5 pixels in size
# label 231 is 12 pixels in size
# label 232 is 2 pixels in size
# label 233 is 1 pixels in size
# label 234 is 116 pixels in size
# label 235 is 2 pixels in size
# label 236 is 28 pixels in size
# label 237 is 1 pixels in size
# label 238 is 2 pixels in size
# label 239 is 1 pixels in size
# label 240 is 3 pixels in size
# label 241 is 5 pixels in size
# label 242 is 4 pixels in size
# label 243 is 2 pixels in size
# label 244 is 100 pixels in size
# label 245 is 1 pixels in size
# label 246 is 1 pixels in size
# label 247 is 3 pixels in size
# label 248 is 3 pixels in size
# label 249 is 4 pixels in size
# label 250 is 1 pixels in size
# label 251 is 1 pixels in size
# label 252 is 3 pixels in size
# label 253 is 6 pixels in size
# label 254 is 4 pixels in size
# label 255 is 1 pixels in size
# label 256 is 4 pixels in size
# label 257 is 3 pixels in size
# label 258 is 5 pixels in size
# label 259 is 45 pixels in size
# label 260 is 1 pixels in size
# label 261 is 2 pixels in size
# label 262 is 1 pixels in size
# label 263 is 2 pixels in size
# label 264 is 16 pixels in size
# label 265 is 2 pixels in size
# label 266 is 1 pixels in size
# label 267 is 26 pixels in size
# label 268 is 1 pixels in size
# label 269 is 29 pixels in size
# label 270 is 3 pixels in size
# label 271 is 2 pixels in size
# label 272 is 4 pixels in size
# label 273 is 6 pixels in size
# label 274 is 1 pixels in size
# label 275 is 13 pixels in size
# label 276 is 8 pixels in size
# label 277 is 2 pixels in size
# label 278 is 2 pixels in size
# label 279 is 1 pixels in size
# label 280 is 2 pixels in size
# label 281 is 4 pixels in size
# label 282 is 5 pixels in size
# label 283 is 2 pixels in size
# label 284 is 1 pixels in size
# label 285 is 2 pixels in size
# label 286 is 1 pixels in size
# label 287 is 15 pixels in size
# label 288 is 1 pixels in size
# label 289 is 3 pixels in size
# label 290 is 2 pixels in size
# label 291 is 295 pixels in size
# label 292 is 8 pixels in size
# label 293 is 1 pixels in size
# label 294 is 12 pixels in size
# label 295 is 5 pixels in size
# label 296 is 2 pixels in size
# label 297 is 5 pixels in size
# label 298 is 4 pixels in size
# label 299 is 6 pixels in size
# label 300 is 5 pixels in size
# label 301 is 1 pixels in size
# label 302 is 1 pixels in size
# label 303 is 3 pixels in size
# label 304 is 8 pixels in size
# label 305 is 12 pixels in size
# label 306 is 5 pixels in size
# label 307 is 1 pixels in size
# label 308 is 7 pixels in size
# label 309 is 90 pixels in size
# label 310 is 44 pixels in size
# label 311 is 8 pixels in size
# label 312 is 1 pixels in size
# label 313 is 1 pixels in size
# label 314 is 2 pixels in size
# label 315 is 3 pixels in size
# label 316 is 1165 pixels in size
# label 317 is 6 pixels in size
# label 318 is 2 pixels in size
# label 319 is 3 pixels in size
# label 320 is 109 pixels in size
# label 321 is 2 pixels in size
# label 322 is 3 pixels in size
# label 323 is 18 pixels in size
# label 324 is 3 pixels in size
# label 325 is 50 pixels in size
# label 326 is 2 pixels in size
# label 327 is 4 pixels in size
# label 328 is 16 pixels in size
# label 329 is 7 pixels in size
# label 330 is 1 pixels in size
# label 331 is 3 pixels in size
# label 332 is 1 pixels in size
# label 333 is 1 pixels in size
# label 334 is 9 pixels in size
# label 335 is 4 pixels in size
# label 336 is 51 pixels in size
# label 337 is 3 pixels in size
# label 338 is 6 pixels in size
# label 339 is 12 pixels in size
# label 340 is 3 pixels in size
# label 341 is 53 pixels in size
# label 342 is 9 pixels in size
# label 343 is 1 pixels in size
# label 344 is 1 pixels in size
# label 345 is 14 pixels in size
# label 346 is 1 pixels in size
# label 347 is 8 pixels in size
# label 348 is 1 pixels in size
# label 349 is 12 pixels in size
# label 350 is 1 pixels in size
# label 351 is 1 pixels in size
# label 352 is 4 pixels in size
# label 353 is 1 pixels in size
# label 354 is 4 pixels in size
# label 355 is 5 pixels in size
# label 356 is 2 pixels in size
# label 357 is 7 pixels in size
# label 358 is 2 pixels in size
# label 359 is 1 pixels in size
# label 360 is 3 pixels in size
# label 361 is 1 pixels in size
# label 362 is 1 pixels in size
# label 363 is 6 pixels in size
# label 364 is 2 pixels in size
# label 365 is 3 pixels in size
# label 366 is 8 pixels in size
# label 367 is 1 pixels in size
# label 368 is 1 pixels in size
# label 369 is 36 pixels in size
# label 370 is 2 pixels in size
# label 371 is 142 pixels in size
# label 372 is 9 pixels in size
# label 373 is 8 pixels in size
# label 374 is 3 pixels in size
# label 375 is 13 pixels in size
# label 376 is 3 pixels in size
# label 377 is 2 pixels in size
# label 378 is 1 pixels in size
# label 379 is 1 pixels in size
# label 380 is 2 pixels in size
# label 381 is 4 pixels in size
# label 382 is 1 pixels in size
# label 383 is 2 pixels in size
# label 384 is 1 pixels in size
# label 385 is 3 pixels in size
# label 386 is 6 pixels in size
# label 387 is 4 pixels in size
# label 388 is 5 pixels in size
# label 389 is 9 pixels in size
# label 390 is 30 pixels in size
# label 391 is 65 pixels in size
# label 392 is 1 pixels in size
# label 393 is 8 pixels in size
# label 394 is 1 pixels in size
# label 395 is 1 pixels in size
# label 396 is 13 pixels in size
# label 397 is 8 pixels in size
# label 398 is 3 pixels in size
# label 399 is 29 pixels in size
# label 400 is 1 pixels in size
# label 401 is 2 pixels in size
# label 402 is 7 pixels in size
# label 403 is 13 pixels in size
# label 404 is 20 pixels in size
# label 405 is 5 pixels in size
# label 406 is 3 pixels in size
# label 407 is 1 pixels in size
# label 408 is 2 pixels in size
# label 409 is 7 pixels in size
# label 410 is 16 pixels in size
# label 411 is 1 pixels in size
# label 412 is 16 pixels in size
# label 413 is 1 pixels in size
# label 414 is 1 pixels in size
# label 415 is 1 pixels in size
# label 416 is 2 pixels in size
# label 417 is 1 pixels in size
# label 418 is 4 pixels in size
# label 419 is 49 pixels in size
# label 420 is 17 pixels in size
# label 421 is 5 pixels in size
# label 422 is 5 pixels in size
# label 423 is 13 pixels in size
# label 424 is 2 pixels in size
# label 425 is 4 pixels in size
# label 426 is 3 pixels in size
# label 427 is 70 pixels in size
# label 428 is 1 pixels in size
# label 429 is 19 pixels in size
# label 430 is 29 pixels in size
# label 431 is 6 pixels in size
# label 432 is 1 pixels in size
# label 433 is 6 pixels in size
# label 434 is 1 pixels in size
# label 435 is 10 pixels in size
# label 436 is 24 pixels in size
# label 437 is 12 pixels in size
# label 438 is 21 pixels in size
# label 439 is 2 pixels in size
# label 440 is 2 pixels in size
# label 441 is 1 pixels in size
# label 442 is 1 pixels in size
# label 443 is 1 pixels in size
# label 444 is 1 pixels in size
# label 445 is 1 pixels in size
# label 446 is 1 pixels in size
# label 447 is 4 pixels in size
# label 448 is 4 pixels in size
# label 449 is 1 pixels in size
# label 450 is 3 pixels in size
# label 451 is 2 pixels in size
# label 452 is 4 pixels in size
# label 453 is 16 pixels in size
# label 454 is 2 pixels in size
# label 455 is 5 pixels in size
# label 456 is 4 pixels in size
# label 457 is 9 pixels in size
# label 458 is 1 pixels in size
# label 459 is 4 pixels in size
# label 460 is 4 pixels in size
# label 461 is 1 pixels in size
# label 462 is 3 pixels in size
# label 463 is 82 pixels in size
# label 464 is 14 pixels in size
# label 465 is 3 pixels in size
# label 466 is 3 pixels in size
# label 467 is 11 pixels in size
# label 468 is 1 pixels in size
# label 469 is 3 pixels in size
# label 470 is 11 pixels in size
# label 471 is 3 pixels in size
# label 472 is 2 pixels in size
# label 473 is 74 pixels in size
# label 474 is 25 pixels in size
# label 475 is 2 pixels in size
# label 476 is 15 pixels in size
# label 477 is 3 pixels in size
# label 478 is 1 pixels in size
# label 479 is 1 pixels in size
# label 480 is 1 pixels in size
# label 481 is 1 pixels in size
# label 482 is 1 pixels in size
# label 483 is 3 pixels in size
# label 484 is 19 pixels in size
# label 485 is 1 pixels in size
# label 486 is 1 pixels in size
# label 487 is 4 pixels in size
# label 488 is 4 pixels in size
# label 489 is 1 pixels in size
# label 490 is 9 pixels in size
# label 491 is 127 pixels in size
# label 492 is 14 pixels in size
# label 493 is 2 pixels in size
# label 494 is 1 pixels in size
# label 495 is 3 pixels in size
# label 496 is 4 pixels in size
# label 497 is 3 pixels in size
# label 498 is 3 pixels in size
# label 499 is 5 pixels in size
# label 500 is 5 pixels in size
# label 501 is 3 pixels in size
# label 502 is 14 pixels in size
# label 503 is 3 pixels in size
# label 504 is 4 pixels in size
# label 505 is 2 pixels in size
# label 506 is 2 pixels in size
# label 507 is 2 pixels in size
# label 508 is 3 pixels in size
# label 509 is 6 pixels in size
# label 510 is 2 pixels in size
# label 511 is 12 pixels in size
# label 512 is 3 pixels in size
# label 513 is 3 pixels in size
# label 514 is 1 pixels in size
# label 515 is 2 pixels in size
# label 516 is 3 pixels in size
# label 517 is 4 pixels in size
# label 518 is 1 pixels in size
# label 519 is 1 pixels in size
# label 520 is 12 pixels in size
# label 521 is 4 pixels in size
# label 522 is 5 pixels in size
# label 523 is 3 pixels in size
# label 524 is 1 pixels in size
# label 525 is 3 pixels in size
# label 526 is 3 pixels in size
# label 527 is 42 pixels in size
# label 528 is 16 pixels in size
# label 529 is 2 pixels in size
# label 530 is 7 pixels in size
# label 531 is 2 pixels in size
# label 532 is 5 pixels in size
# label 533 is 12 pixels in size
# label 534 is 1 pixels in size
# label 535 is 15 pixels in size
# label 536 is 22 pixels in size
# label 537 is 16 pixels in size
# label 538 is 109 pixels in size
# label 539 is 1 pixels in size
# label 540 is 1 pixels in size
# label 541 is 9 pixels in size
# label 542 is 5 pixels in size
# label 543 is 6 pixels in size
# label 544 is 1 pixels in size
# label 545 is 1 pixels in size
# label 546 is 3 pixels in size
# label 547 is 3 pixels in size
# label 548 is 1 pixels in size
# label 549 is 5 pixels in size
# label 550 is 1 pixels in size
# label 551 is 9 pixels in size
# label 552 is 4 pixels in size
# label 553 is 4 pixels in size
# label 554 is 2 pixels in size
# label 555 is 1 pixels in size
# label 556 is 24 pixels in size
# label 557 is 2 pixels in size
# label 558 is 15 pixels in size
# label 559 is 3 pixels in size
# label 560 is 5 pixels in size
# label 561 is 4 pixels in size
# label 562 is 3 pixels in size
# label 563 is 1 pixels in size
# label 564 is 6 pixels in size
# label 565 is 4 pixels in size
# label 566 is 7 pixels in size
# label 567 is 6 pixels in size
# label 568 is 1 pixels in size
# label 569 is 3 pixels in size
# label 570 is 1 pixels in size
# label 571 is 1 pixels in size
# label 572 is 15 pixels in size
# label 573 is 2 pixels in size
# label 574 is 1 pixels in size
# label 575 is 13 pixels in size
# label 576 is 2 pixels in size
# label 577 is 2 pixels in size
# label 578 is 77 pixels in size
# label 579 is 3 pixels in size
# label 580 is 1 pixels in size
# label 581 is 1 pixels in size
# label 582 is 1 pixels in size
# label 583 is 6 pixels in size
# label 584 is 4 pixels in size
# label 585 is 2 pixels in size
# label 586 is 2 pixels in size
# label 587 is 6 pixels in size
# label 588 is 3 pixels in size
# label 589 is 2 pixels in size
# label 590 is 1 pixels in size
# label 591 is 75 pixels in size
# label 592 is 1 pixels in size
# label 593 is 4 pixels in size
# label 594 is 13 pixels in size
# label 595 is 37 pixels in size
# label 596 is 4 pixels in size
# label 597 is 35 pixels in size
# label 598 is 5 pixels in size
# label 599 is 18 pixels in size
# label 600 is 3 pixels in size
# label 601 is 1 pixels in size
# label 602 is 3 pixels in size
# label 603 is 1 pixels in size
# label 604 is 1 pixels in size
# label 605 is 2 pixels in size
# label 606 is 1 pixels in size
# label 607 is 1 pixels in size
# label 608 is 1 pixels in size
# label 609 is 1 pixels in size
# label 610 is 2 pixels in size
# label 611 is 8 pixels in size
# label 612 is 1 pixels in size
# label 613 is 1 pixels in size
# label 614 is 2 pixels in size
# label 615 is 2 pixels in size
# label 616 is 3 pixels in size
# label 617 is 24 pixels in size
# label 618 is 1 pixels in size
# label 619 is 2 pixels in size
# label 620 is 4 pixels in size
# label 621 is 5 pixels in size
# label 622 is 7 pixels in size
# label 623 is 1 pixels in size
# label 624 is 11 pixels in size
# label 625 is 94 pixels in size
# label 626 is 4 pixels in size
# label 627 is 1 pixels in size
# label 628 is 1 pixels in size
# label 629 is 11 pixels in size
# label 630 is 2 pixels in size
# label 631 is 2 pixels in size
# label 632 is 2 pixels in size
# label 633 is 10 pixels in size
# label 634 is 1 pixels in size
# label 635 is 9 pixels in size
# label 636 is 3 pixels in size
# label 637 is 21 pixels in size
# label 638 is 4 pixels in size
# label 639 is 2 pixels in size
# label 640 is 4 pixels in size
# label 641 is 2 pixels in size
# label 642 is 3 pixels in size
# label 643 is 2 pixels in size
# label 644 is 1 pixels in size
# label 645 is 1 pixels in size
# label 646 is 1 pixels in size

# %% [markdown]
# ## 4. Global Navigation

# %%
endsize = [100, 100]

#this line generates the original enposition, thymio position, and the obstacle channel
thymiopos, endpos, obstacleimage = downsamplingprep(img, endsize, 5, 5)
print(thymiopos, endpos)

#this line turns obstacleimage into its downsampled version with enlarged obstacles
preppedimage = downsampling(obstacleimage, endsize, 5, 0.2)


plt.imshow(preppedimage)
plt.plot()
# Out:
# [15, 13] [55, 19]
# c:\Users\adela\OneDrive\Documents\EPFL_MA3\basics_of_mobile_robotics\New_project\Thytanic\global_navigation.py:34: RuntimeWarning: invalid value encountered in scalar divide
#   avg = np.sum(window) / window.size
# []

# %%
path, exploredpoints, unexploredpoints = pathfinder(thymiopos, endpos, preppedimage)

testimage = preppedimage.copy()

for k in path:
    testimage[k[0], k[1]] += 2
    
for k in exploredpoints:
    testimage[k[0], k[1]] += 3

for k in unexploredpoints:
    testimage[k[0], k[1]] += 4

plt.imshow(testimage)
plt.plot()

print(path.shape)
# Out:
# (47, 2)

# %% [markdown]
# ## 5. Kalman Filter

# %% [markdown]
# ## 6. Local Navigation

# %% [markdown]
# ![Local Navigation Algorithm](img/local_nav.png)

# %%
# Main script to establish connection and start movement
try:
    print("Connecting to Thytanic...")
    thytanic.establish_connection()
    print("Connection established!")

    # Set the robot to GLOBAL_MOVEMENT state
    thytanic.x_est = np.array([thymiopos[1], 0, thymiopos[0], 0,-np.pi/2,0]) #position, velocity (x,y,angle)
    thytanic.P_est = np.eye(6) # TO TUNE
    thytanic.goal_idx = 0
    thytanic.robot_state = ThytanicState.GLOBAL_MOVEMENT
    #thytanic.set_wheel_speed(100, 100)
    print("Thytanic state set to GLOBAL_MOVEMENT.")
    x_estimated = []
    ########################
    
    path = path[::5]
    path = path[2:]
    path = np.array([[p[1], p[0]] for p in path])
    ##########################
    # Start the robot movement loop
    while True:
        # apply kalman filter and get the estimated positions thytanic.x_est
        kalman_filter(thytanic,None) #no camera 
        x_estimated.append(thytanic.x_est)
        #print("x_est", thytanic.x_est)
        thytanic.goal = path[thytanic.goal_idx] # get the (x,y) coordinates of the goal point
        print("goal", thytanic.goal)
        #print("goal_idx", thytanic.goal_idx)
        thytanic.update_robot_state()

        # Print the proximity sensor values
        sensor_values = thytanic.read_proximity_sensors()
        #print("Proximity sensor readings -- threshold of 2000 for detection:", sensor_values)
        
        if thytanic.goal_idx >= len(path):
            thytanic.robot_state = ThytanicState.STOP
            thytanic.update_robot_state()
            print("Goal reached!")
            break 

except KeyboardInterrupt:
    # Handle interruption and stop the robot safely
    print("\nStopping the Thytanic...")
    thytanic.disconnect()
    print("Thytanic stopped and disconnected.")

finally:
    print("Session ended.")
    plt.figure()
    plt.plot(np.array(x_estimated)[:,0], np.array(x_estimated)[:,2], label='Estimated')
    plt.plot(path[:,0], path[:,1], label='True')
    # Plot the path
    plt.legend()
# Out:
# Connecting to Thytanic...
# Connection established!
# Thytanic state set to GLOBAL_MOVEMENT.
# goal [13 25]
# x 13.0 y 15.0 theta -1.5707963267948966
# goal index 0
# delta_x 0.0 delta_y 10.0
# alpha 0.0
# v 200 omega 0.0
# goal [13 25]
# x 13.0 y 15.224106990327225 theta -1.5726587117560646
# goal index 0
# delta_x 0.0 delta_y 9.775893009672775
# alpha 0.0018623849611680843
# v 200 omega 0.037247699223361685
# goal [13 25]
# x 12.999571427189192 y 15.641629850780816 theta -1.575925949045647
# goal index 0
# delta_x 0.00042857281080799225 delta_y 9.358370149219184
# alpha 0.0051754179185510285
# v 200 omega 0.10350835837102057
# goal [13 25]
# x 12.997961837380439 y 16.162829430052536 theta -1.578918925358048
# goal index 0
# delta_x 0.0020381626195611346 delta_y 8.837170569947464
# alpha 0.008353233761068113
# v 200 omega 0.16706467522136226
# goal [13 25]
# x 12.994734346312688 y 16.735403647769168 theta -1.5800115214909634
# goal index 0
# delta_x 0.005265653687311911 delta_y 8.264596352230832
# alpha 0.00985232841081607
# v 200 omega 0.19704656821632138
# goal [13 25]
# x 12.990091129139874 y 17.341277196235147 theta -1.5779792029572475
# goal index 0
# delta_x 0.009908870860126484 delta_y 7.658722803764853
# alpha 0.008476677437723179
# v 200 omega 0.16953354875446358
# goal [13 25]
# x 12.985166700591268 y 17.968886228121985 theta -1.5740417552080395
# goal index 0
# delta_x 0.014833299408731904 delta_y 7.031113771878015
# alpha 0.005355090962194886
# v 200 omega 0.10710181924389772
# goal [13 25]
# x 12.981441684354905 y 18.593007794409587 theta -1.5705980577929046
# goal index 0
# delta_x 0.01855831564509458 delta_y 6.406992205590413
# alpha 0.0026982951185219317
# v 200 omega 0.053965902370438634
# goal [13 25]
# x 12.979597896886153 y 19.206780312414743 theta -1.566671930087728
# goal index 0
# delta_x 0.020402103113847048 delta_y 5.793219687585257
# alpha -0.0006026903212748014
# v 200 omega -0.012053806425496028
# goal [13 25]
# x 12.979923589927568 y 19.827145351232346 theta -1.5651874413712352
# goal index 0
# delta_x 0.020076410072432438 delta_y 5.172854648767654
# alpha -0.0017277964248720856
# v 200 omega -0.03455592849744171
# goal [13 25]
# x 12.981972574257188 y 20.44695644718654 theta -1.5657037638201752
# goal index 0
# delta_x 0.018027425742811687 delta_y 4.55304355281346
# alpha -0.0011331605817763712
# v 200 omega -0.022663211635527425
# goal [13 25]
# x 12.984785972591009 y 21.06788463380375 theta -1.5668593793192471
# goal index 0
# delta_x 0.015214027408990916 delta_y 3.93211536619625
# alpha -6.7795614031807e-05
# v 200 omega -0.0013559122806361401
# goal [13 25]
# x 12.987449186696894 y 21.664967259015185 theta -1.573619591382638
# goal index 0
# delta_x 0.012550813303105812 delta_y 3.335032740984815
# alpha 0.006586572185469208
# v 200 omega 0.13173144370938417
# goal [13 25]
# x 12.988302276294853 y 22.263997475198483 theta -1.5811278917955196
# goal index 0
# delta_x 0.011697723705147212 delta_y 2.736002524801517
# alpha 0.014607018814287942
# v 200 omega 0.29214037628575884
# goal [13 25]
# x 12.985738912672486 y 22.880387499188608 theta -1.5848143714141703
# goal index 0
# delta_x 0.014261087327513522 delta_y 2.1196125008113924
# alpha 0.020746100873466178
# v 200 omega 0.41492201746932356
# goal [13 25]
# x 12.980005662878504 y 23.49380590587586 theta -1.584368231331709
# goal index 0
# delta_x 0.019994337121495676 delta_y 1.5061940941241403
# alpha 0.026845866282218855
# v 200 omega 0.5369173256443771
# goal [13 30]
# x 12.972559396631604 y 24.110706132806712 theta -1.5827869390867961
# goal index 1
# delta_x 0.0274406033683956 delta_y 5.889293867193288
# alpha 0.016649983247196243
# v 200 omega 0.33299966494392486
# goal [13 30]
# x 12.965134682355224 y 24.70874137805138 theta -1.583078797812108
# goal index 1
# delta_x 0.034865317644776184 delta_y 5.2912586219486215
# alpha 0.01887160520161979
# v 200 omega 0.3774321040323958
# goal [13 30]
# x 12.9577618973808 y 25.309664979634608 theta -1.5835802361571996
# goal index 1
# delta_x 0.04223810261919958 delta_y 4.690335020365392
# alpha 0.021789014692020325
# v 200 omega 0.4357802938404065
# goal [13 30]
# x 12.949357650684629 y 25.98211891495248 theta -1.571952770863194
# goal index 1
# delta_x 0.05064234931537115 delta_y 4.01788108504752
# alpha 0.01376001960990969
# v 200 omega 0.2752003921981938
# goal [13 30]
# x 12.943565236050588 y 26.642375608730585 theta -1.5597783265075686
# goal index 1
# delta_x 0.056434763949411604 delta_y 3.3576243912694146
# alpha 0.005788361553385135
# v 200 omega 0.1157672310677027
# goal [13 30]
# x 12.943883880829567 y 27.27551894811091 theta -1.554800677000551
# goal index 1
# delta_x 0.05611611917043291 delta_y 2.7244810518890894
# alpha 0.0045984320236800436
# v 200 omega 0.09196864047360087
# goal [13 30]
# x 12.949149464401506 y 27.885858193543502 theta -1.5579323479870235
# goal index 1
# delta_x 0.05085053559849406 delta_y 2.114141806456498
# alpha 0.011183950582557056
# v 200 omega 0.22367901165114112
# goal [13 30]
# x 12.95627451055838 y 28.483739852371183 theta -1.563563546811204
# goal index 1
# delta_x 0.043725489441619914 delta_y 1.5162601476288167
# alpha 0.021596952592936036
# v 200 omega 0.4319390518587207
# goal [13 35]
# x 12.962492015673936 y 29.084657957970755 theta -1.5678575014371212
# goal index 2
# delta_x 0.03750798432606395 delta_y 5.915342042029245
# alpha 0.003401886877176352
# v 200 omega 0.06803773754352704
# goal [13 35]
# x 12.966606127019372 y 29.698073083565152 theta -1.5724353527431094
# goal index 2
# delta_x 0.03339387298062846 delta_y 5.301926916434848
# alpha 0.007937383495416839
# v 200 omega 0.15874766990833677
# goal [13 35]
# x 12.968220402073344 y 30.32326416349404 theta -1.575493638562261
# goal index 2
# delta_x 0.03177959792665597 delta_y 4.676735836505959
# alpha 0.011492459046460457
# v 200 omega 0.22984918092920914
# goal [13 35]
# x 12.967463411164035 y 30.951693134112684 theta -1.5769266926353926
# goal index 2
# delta_x 0.03253658883596522 delta_y 4.048306865887316
# alpha 0.014167278400918804
# v 200 omega 0.28334556801837607
# goal [13 35]
# x 12.965049600249362 y 31.57302862665051 theta -1.5779026761981019
# goal index 2
# delta_x 0.034950399750638184 delta_y 3.4269713733494918
# alpha 0.01730462194924387
# v 200 omega 0.3460924389848774
# goal [13 35]
# x 12.961573635229279 y 32.18950268770449 theta -1.5802934313862251
# goal index 2
# delta_x 0.03842636477072148 delta_y 2.81049731229551
# alpha 0.023168695897010094
# v 200 omega 0.4633739179402019
# goal [13 35]
# x 12.956416378039751 y 32.86480413920709 theta -1.5701675375219948
# goal index 2
# delta_x 0.043583621960248564 delta_y 2.135195860792912
# alpha 0.019780378446593083
# v 200 omega 0.39560756893186166
# goal [13 35]
# x 12.952865507106672 y 33.53873766212928 theta -1.556120074116674
# goal index 2
# delta_x 0.04713449289332772 delta_y 1.4612623378707212
# alpha 0.017568577588599643
# v 200 omega 0.35137155177199286
# goal [13 40]
# x 12.955256332048718 y 34.18990245521754 theta -1.5485875071068573
# goal index 3
# delta_x 0.04474366795128226 delta_y 5.810097544782458
# alpha -0.014507953545956909
# v 200 omega -0.2901590709191382
# goal [13 40]
# x 12.964129311799736 y 34.849198419272696 theta -1.5406148259022925
# goal index 3
# delta_x 0.035870688200263956 delta_y 5.150801580727304
# alpha -0.0232175152368832
# v 200 omega -0.46435030473766403
# goal [13 40]
# x 12.97829359319383 y 35.4998402056302 theta -1.5343578098407087
# goal index 3
# delta_x 0.0217064068061692 delta_y 4.5001597943698
# alpha -0.031615079685155534
# v 200 omega -0.6323015937031107
# goal [13 40]
# x 12.997078625495798 y 36.14076074133603 theta -1.532863700946465
# goal index 3
# delta_x 0.0029213745042024897 delta_y 3.859239258663969
# alpha -0.037175644031447685
# v 200 omega -0.7435128806289537
# goal [13 40]
# x 13.017718544693729 y 36.746306870546746 theta -1.5385106028276097
# goal index 3
# delta_x -0.01771854469372869 delta_y 3.2536931294532536
# alpha -0.03773134186733662
# v 200 omega -0.7546268373467324
# goal [13 40]
# x 13.040031419919579 y 37.401651602097175 theta -1.5319204252052814
# goal index 3
# delta_x -0.04003141991957904 delta_y 2.598348397902825
# alpha -0.05428116945869377
# v 200 omega -1.0856233891738754
# goal [13 40]
# x 13.063426227111485 y 38.06518434945005 theta -1.520812842254931
# goal index 3
# delta_x -0.06342622711148493 delta_y 1.9348156505499503
# alpha -0.08275328451700359
# v 200 omega -1.6550656903400718
# goal [13 45]
# x 13.08923911954072 y 38.68780868001675 theta -1.5180344146930793
# goal index 4
# delta_x -0.08923911954071961 delta_y 6.312191319983249
# alpha -0.06689855186548432
# v 200 omega -1.3379710373096865
# goal [13 45]
# x 13.118899049379438 y 39.30793219546444 theta -1.5217264589032606
# goal index 4
# delta_x -0.11889904937943818 delta_y 5.6920678045355615
# alpha -0.06995538170691296
# v 200 omega -1.3991076341382591
# goal [13 45]
# x 13.150363118241648 y 39.943504972674326 theta -1.531622388504697
# goal index 4
# delta_x -0.15036311824164805 delta_y 5.056495027325674
# alpha -0.06890180720766037
# v 200 omega -1.3780361441532074
# goal [13 45]
# x 13.180528365061647 y 40.610372970269694 theta -1.531649511621173
# goal index 4
# delta_x -0.18052836506164738 delta_y 4.389627029730306
# alpha -0.08024978078126077
# v 200 omega -1.6049956156252154
# goal [13 45]
# x 13.207708401603414 y 41.264753526619316 theta -1.526117522685208
# goal index 4
# delta_x -0.20770840160341386 delta_y 3.735246473380684
# alpha -0.10022927620019728
# v 131.93575282732385 omega -2.0045855240039456
# goal [13 45]
# x 13.230576732254605 y 41.811809253049546 theta -1.5256324953063467
# goal index 4
# delta_x -0.23057673225460462 delta_y 3.188190746950454
# alpha -0.11736025814536344
# v 116.20620211227508 omega -2.3472051629072688
# goal [13 45]
# x 13.250990799105706 y 42.28020431510136 theta -1.526492040711299
# goal index 4
# delta_x -0.2509907991057059 delta_y 2.719795684898642
# alpha -0.13632661252743694
# v 100.47968051900769 omega -2.726532250548739
# goal [13 45]
# x 13.269684744145918 y 42.70292341746244 theta -1.5306300376270006
# goal index 4
# delta_x -0.26968474414591803 delta_y 2.2970765825375565
# alpha -0.15703475605431705
# v 83.84819851495023 omega -3.140695121086341
# goal [13 45]
# x 13.28521381556899 y 43.06406747858493 theta -1.5386396960207929
# goal index 4
# delta_x -0.2852138155689907 delta_y 1.9359325214150687
# alpha -0.17843071308729064
# v 67.13255557246438 omega -3.5686142617458128
# goal [14 49]
# x 13.296918120000578 y 43.36422768657369 theta -1.5510420187190381
# goal index 5
# delta_x 0.7030818799994218 delta_y 5.635772313426308
# alpha 0.10435789431574638
# v 173.68559687915456 omega 2.0871578863149276
# goal [14 49]
# x 13.306121973575276 y 43.68232145143844 theta -1.5621549593516206
# goal index 5
# delta_x 0.6938780264247235 delta_y 5.31767854856156
# alpha 0.12111068373457634
# v 167.94783688162624 omega 2.422213674691527
# goal [14 49]
# x 13.313115523719693 y 44.09028886208431 theta -1.5661200701488942
# goal index 5
# delta_x 0.6868844762803068 delta_y 4.909711137915693
# alpha 0.1343247797435878
# v 160.09070233327435 omega 2.686495594871756
# goal [14 49]
# x 13.317600002219686 y 44.530994723796155 theta -1.5693012594177316
# goal index 5
# delta_x 0.6823999977803137 delta_y 4.469005276203845
# alpha 0.15003067451237473
# v 150.86900769876712 omega 3.0006134902474946
# goal [14 49]
# x 13.320039609826251 y 44.97028326061301 theta -1.5692396721506827
# goal index 5
# delta_x 0.6799603901737488 delta_y 4.029716739386991
# alpha 0.16560525830572348
# v 140.7733195164315 omega 3.3121051661144696
# goal [14 49]
# x 13.321357571917778 y 45.390271267801054 theta -1.5692695572239836
# goal index 5
# delta_x 0.6786424280822221 delta_y 3.6097287321989455
# alpha 0.18430774804880423
# v 130.10001708120905 omega 3.6861549609760846
# goal [14 49]
# x 13.322250432862823 y 45.80398857425853 theta -1.5659237835070927
# goal index 5
# delta_x 0.6777495671371767 delta_y 3.1960114257414673
# alpha 0.2040928356530427
# v 118.38976400016973 omega 4.081856713060854
# goal [14 49]
# x 13.323510984404544 y 46.21960766599477 theta -1.5573595162195921
# goal index 5
# delta_x 0.6764890155954557 delta_y 2.780392334005228
# alpha 0.2252327394958833
# v 105.13482020168776 omega 4.504654789917666
# goal [14 49]
# x 13.326714632833498 y 46.64289428343734 theta -1.538325390957446
# goal index 5
# delta_x 0.6732853671665016 delta_y 2.357105716562657
# alpha 0.24576070558268648
# v 89.66508517443395 omega 4.91521411165373
# goal [14 49]
# x 13.333453742682567 y 47.03500694398881 theta -1.5164107550440227
# goal index 5
# delta_x 0.6665462573174334 delta_y 1.9649930560111883
# alpha 0.2726450649023906
# v 72.99445034784291 omega 5.452901298047812
# goal [14 49]
# x 13.344801786671658 y 47.377611093226285 theta -1.497324968613947
# goal index 5
# delta_x 0.655198213328342 delta_y 1.6223889067737147
# alpha 0.3103476924006632
# v 55.94411392443287 omega 6.2069538480132636
# goal [16 52]
# x 13.361757388513123 y 47.6983448697266 theta -1.4734920641119398
# goal index 6
# delta_x 2.638242611486877 delta_y 4.301655130273403
# alpha 0.4528436338192965
# v 161.86438591804068 omega 9.056872676385929
# goal [16 52]
# x 13.384047019177785 y 48.000974932646656 theta -1.4500718831873285
# goal index 6
# delta_x 2.6159529808222146 delta_y 3.999025067353344
# alpha 0.45856102301082624
# v 156.4156233248098 omega 9.171220460216524
# goal [16 52]
# x 13.420348448254963 y 48.35847640597231 theta -1.4245833873090592
# goal index 6
# delta_x 2.5796515517450374 delta_y 3.6415235940276887
# alpha 0.47012770164601236
# v 149.57440452256162 omega 9.402554032920246
# goal [16 52]
# x 13.471983645222004 y 48.77068367300553 theta -1.3939085058121148
# goal index 6
# delta_x 2.5280163547779964 delta_y 3.2293163269944714
# alpha 0.48729761779200054
# v 141.12650233866296 omega 9.74595235584001
# goal [16 52]
# x 13.536999738336604 y 49.19967478608643 theta -1.3597018916066095
# goal index 6
# delta_x 2.463000261663396 delta_y 2.800325213913567
# alpha 0.5103015615565943
# v 131.62389948824986 omega 10.206031231131886
# goal [16 52]
# x 13.616034978824898 y 49.63373497461873 theta -1.3253456743004137
# goal index 6
# delta_x 2.3839650211751025 delta_y 2.366265025381267
# alpha 0.5436736281025543
# v 121.16263994385702 omega 10.873472562051084
# goal [16 52]
# x 13.706744193649017 y 50.05596832514237 theta -1.2886346962455342
# goal index 6
# delta_x 2.2932558063509827 delta_y 1.9440316748576265
# alpha 0.5854675905618064
# v 110.07345198800986 omega 11.709351811236129
# goal [16 52]
# x 13.79603053300984 y 50.41863915142195 theta -1.2547236559449888
# goal index 6
# delta_x 2.2039694669901593 delta_y 1.5813608485780506
# alpha 0.6323452048100084
# v 99.79065506538191 omega 12.646904096200169
# goal [16 52]
# x 13.882041525983098 y 50.72334955426329 theta -1.2249539921184158
# goal index 6
# delta_x 2.117958474016902 delta_y 1.2766504457367134
# alpha 0.6824972319223392
# v 90.54201711869771 omega 13.649944638446785
# goal [16 52]
# x 13.977852073523529 y 51.02019825974862 theta -1.1900813396902004
# goal index 6
# delta_x 2.022147926476471 delta_y 0.9798017402513821
# alpha 0.7388819791905652
# v 80.96043796056041 omega 14.777639583811304
# goal [16 52]
# x 14.078212874018648 y 51.30019557572848 theta -1.1509197694383215
# goal index 6
# delta_x 1.9217871259813517 delta_y 0.6998044242715196
# alpha 0.8017017873784131
# v 71.55133887605096 omega 16.03403574756826
# goal [16 52]
# x 14.176594043550187 y 51.547625887332735 theta -1.1073937552892272
# goal index 6
# delta_x 1.8234059564498128 delta_y 0.4523741126672647
# alpha 0.8642107924634299
# v 63.057125519338506 omega 17.284215849268598
# goal [19 54]
# x 14.277491130893795 y 51.77430139498877 theta -1.0599086930358677
# goal index 7
# delta_x 4.722508869106205 delta_y 2.2256986050112317
# alpha 0.6194869854829177
# v 165.26336170095607 omega 12.389739709658354
# goal [19 54]
# x 14.369972801152926 y 51.96255477161294 theta -1.0175337299078566
# goal index 7
# delta_x 4.630027198847074 delta_y 2.0374452283870568
# alpha 0.6029846476394753
# v 162.10682902395646 omega 12.059692952789508
# goal [19 54]
# x 14.524326187479096 y 52.23013421707878 theta -0.9785545420087597
# goal index 7
# delta_x 4.475673812520904 delta_y 1.7698657829212223
# alpha 0.6019843400437515
# v 157.13014223397593 omega 12.039686800875028
# goal [19 54]
# x 14.751159699271328 y 52.590161668605695 theta -0.9379108328716786
# goal index 7
# delta_x 4.248840300728672 delta_y 1.4098383313943046
# alpha 0.617525410160529
# v 149.88723242284675 omega 12.35050820321058
# goal [19 54]
# x 15.007850989285553 y 52.9675111255741 theta -0.8981968048495643
# goal index 7
# delta_x 3.9921490107144475 delta_y 1.0324888744259013
# alpha 0.6451125725973876
# v 141.67033391406693 omega 12.902251451947752
# goal [19 54]
# x 15.271092077305461 y 53.32603438805737 theta -0.8616357625949771
# goal index 7
# delta_x 3.728907922694539 delta_y 0.6739656119426272
# alpha 0.6828254149324811
# v 133.21879024948387 omega 13.656508298649621
# goal [19 54]
# x 15.535256113609538 y 53.65924306699457 theta -0.8255082605972297
# goal index 7
# delta_x 3.464743886390462 delta_y 0.3407569330054301
# alpha 0.7274737165287126
# v 124.74518183931815 omega 14.549474330574252
# goal [19 54]
# x 15.801348849108814 y 53.97065725544204 theta -0.7875045082302159
# goal index 7
# delta_x 3.1986511508911857 delta_y 0.029342744557958156
# alpha 0.7783312911066168
# v 116.27712801428946 omega 15.566625822132336
# goal [19 54]
# x 16.04972926013091 y 54.24199311621295 theta -0.7518377406110097
# goal index 7
# delta_x 2.95027073986909 delta_y -0.24199311621295294
# alpha 0.8336785655842198
# v 108.52496478862473 omega 16.673571311684398
# goal [19 54]
# x 16.28808738573922 y 54.48336649570547 theta -0.7114088154860984
# goal index 7
# delta_x 2.711912614260779 delta_y -0.48336649570546797
# alpha 0.8877947479297554
# v 101.32914848999184 omega 17.755894958595107
# goal [19 54]
# x 16.528378739086236 y 54.708360282895434 theta -0.6645144175823373
# goal index 7
# delta_x 2.471621260913764 delta_y -0.7083602828954341
# alpha 0.9436303709779981
# v 94.4343711364116 omega 18.872607419559962
# goal [19 54]
# x 16.764460971316872 y 54.911830737938914 theta -0.6113407490445094
# goal index 7
# delta_x 2.235539028683128 delta_y -0.9118307379389137
# alpha 0.9986213642330033
# v 88.14287376801792 omega 19.972427284660064
# goal [19 54]
# x 16.997116975359425 y 55.0938580527183 theta -0.5538427065695866
# goal index 7
# delta_x 2.0028830246405747 delta_y -1.0938580527183035
# alpha 1.0537189090655885
# v 82.51042744072198 omega 21.074378181311772
# goal [19 54]
# x 17.22742941401613 y 55.255375700493374 theta -0.49634478997230586
# goal index 7
# delta_x 1.7725705859838712 delta_y -1.2553757004933743
# alpha 1.112568419227862
# v 77.56898020247715 omega 22.25136838455724
# goal [19 54]
# x 17.46854997125447 y 55.404126683300575 theta -0.4372814498031253
# goal index 7
# delta_x 1.5314500287455317 delta_y -1.404126683300575
# alpha 1.1793342644829052
# v 73.12700423708208 omega 23.586685289658107
# goal [19 54]
# x 17.717938884192613 y 55.53903180379134 theta -0.3777361130687168
# goal index 7
# delta_x 1.2820611158073874 delta_y -1.5390318037913389
# alpha 1.2539726496987393
# v 69.46822713610072 omega 25.079452993974787
# goal [19 54]
# x 17.974121796136842 y 55.65859645971186 theta -0.31713469682798373
# goal index 7
# delta_x 1.025878203863158 delta_y -1.658596459711859
# alpha 1.3340036988287234
# v 66.79435351274017 omega 26.68007397657447
# Goal reached!
# Session ended.

# %% [markdown]
# ## 7. Main Loop

# %% [markdown]
# ## 8. Stopping

# %% [markdown]
# ## 9. Conclusion
